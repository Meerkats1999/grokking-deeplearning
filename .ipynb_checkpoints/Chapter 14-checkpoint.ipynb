# %%
import numpy as np

class Tensor (object):
    
    def __init__(self,data,
                 autograd=False,
                 creators=None,
                 creation_op=None,
                 id=None):
        
        self.data = np.array(data)
        self.autograd = autograd
        self.grad = None

        if(id is None):
            self.id = np.random.randint(0,1000000000)
        else:
            self.id = id
        
        self.creators = creators
        self.creation_op = creation_op
        self.children = {}
        
        if(creators is not None):
            for c in creators:
                if(self.id not in c.children):
                    c.children[self.id] = 1
                else:
                    c.children[self.id] += 1

    def all_children_grads_accounted_for(self):
        for id,cnt in self.children.items():
            if(cnt != 0):
                return False
        return True 
        
    def backward(self,grad=None, grad_origin=None):
        if(self.autograd):
 
            if(grad is None):
                grad = Tensor(np.ones_like(self.data))

            if(grad_origin is not None):
                if(self.children[grad_origin.id] == 0):
                    return
                    print(self.id)
                    print(self.creation_op)
                    print(len(self.creators))
                    for c in self.creators:
                        print(c.creation_op)
                    raise Exception("cannot backprop more than once")
                else:
                    self.children[grad_origin.id] -= 1

            if(self.grad is None):
                self.grad = grad
            else:
                self.grad += grad
            
            assert grad.autograd == False
            
            if(self.creators is not None and 
               (self.all_children_grads_accounted_for() or 
                grad_origin is None)):

                if(self.creation_op == "add"):
                    self.creators[0].backward(self.grad, self)
                    self.creators[1].backward(self.grad, self)
                    
                if(self.creation_op == "sub"):
                    self.creators[0].backward(Tensor(self.grad.data), self)
                    self.creators[1].backward(Tensor(self.grad.__neg__().data), self)

                if(self.creation_op == "mul"):
                    new = self.grad * self.creators[1]
                    self.creators[0].backward(new , self)
                    new = self.grad * self.creators[0]
                    self.creators[1].backward(new, self)                    
                    
                if(self.creation_op == "mm"):
                    c0 = self.creators[0]
                    c1 = self.creators[1]
                    new = self.grad.mm(c1.transpose())
                    c0.backward(new)
                    new = self.grad.transpose().mm(c0).transpose()
                    c1.backward(new)
                    
                if(self.creation_op == "transpose"):
                    self.creators[0].backward(self.grad.transpose())

                if("sum" in self.creation_op):
                    dim = int(self.creation_op.split("_")[1])
                    self.creators[0].backward(self.grad.expand(dim,
                                                               self.creators[0].data.shape[dim]))

                if("expand" in self.creation_op):
                    dim = int(self.creation_op.split("_")[1])
                    self.creators[0].backward(self.grad.sum(dim))
                    
                if(self.creation_op == "neg"):
                    self.creators[0].backward(self.grad.__neg__())
                    
                if(self.creation_op == "sigmoid"):
                    ones = Tensor(np.ones_like(self.grad.data))
                    self.creators[0].backward(self.grad * (self * (ones - self)))
                
                if(self.creation_op == "tanh"):
                    ones = Tensor(np.ones_like(self.grad.data))
                    self.creators[0].backward(self.grad * (ones - (self * self)))
                
                if(self.creation_op == "index_select"):
                    new_grad = np.zeros_like(self.creators[0].data)
                    indices_ = self.index_select_indices.data.flatten()
                    grad_ = grad.data.reshape(len(indices_), -1)
                    for i in range(len(indices_)):
                        new_grad[indices_[i]] += grad_[i]
                    self.creators[0].backward(Tensor(new_grad))
                    
                if(self.creation_op == "cross_entropy"):
                    dx = self.softmax_output - self.target_dist
                    self.creators[0].backward(Tensor(dx))
                    
    def __add__(self, other):
        if(self.autograd and other.autograd):
            return Tensor(self.data + other.data,
                          autograd=True,
                          creators=[self,other],
                          creation_op="add")
        return Tensor(self.data + other.data)

    def __neg__(self):
        if(self.autograd):
            return Tensor(self.data * -1,
                          autograd=True,
                          creators=[self],
                          creation_op="neg")
        return Tensor(self.data * -1)
    
    def __sub__(self, other):
        if(self.autograd and other.autograd):
            return Tensor(self.data - other.data,
                          autograd=True,
                          creators=[self,other],
                          creation_op="sub")
        return Tensor(self.data - other.data)
    
    def __mul__(self, other):
        if(self.autograd and other.autograd):
            return Tensor(self.data * other.data,
                          autograd=True,
                          creators=[self,other],
                          creation_op="mul")
        return Tensor(self.data * other.data)    

    def sum(self, dim):
        if(self.autograd):
            return Tensor(self.data.sum(dim),
                          autograd=True,
                          creators=[self],
                          creation_op="sum_"+str(dim))
        return Tensor(self.data.sum(dim))
    
    def expand(self, dim,copies):

        trans_cmd = list(range(0,len(self.data.shape)))
        trans_cmd.insert(dim,len(self.data.shape))
        new_data = self.data.repeat(copies).reshape(list(self.data.shape) + [copies]).transpose(trans_cmd)
        
        if(self.autograd):
            return Tensor(new_data,
                          autograd=True,
                          creators=[self],
                          creation_op="expand_"+str(dim))
        return Tensor(new_data)
    
    def transpose(self):
        if(self.autograd):
            return Tensor(self.data.transpose(),
                          autograd=True,
                          creators=[self],
                          creation_op="transpose")
        
        return Tensor(self.data.transpose())
    
    def mm(self, x):
        if(self.autograd):
            return Tensor(self.data.dot(x.data),
                          autograd=True,
                          creators=[self,x],
                          creation_op="mm")
        return Tensor(self.data.dot(x.data))
    
    def sigmoid(self):
        if(self.autograd):
            return Tensor(1 / (1 + np.exp(-self.data)),
                          autograd=True,
                          creators=[self],
                          creation_op="sigmoid")
        return Tensor(1 / (1 + np.exp(-self.data)))

    def tanh(self):
        if(self.autograd):
            return Tensor(np.tanh(self.data),
                          autograd=True,
                          creators=[self],
                          creation_op="tanh")
        return Tensor(np.tanh(self.data))
    
    def index_select(self, indices):

        if(self.autograd):
            new = Tensor(self.data[indices.data],
                         autograd=True,
                         creators=[self],
                         creation_op="index_select")
            new.index_select_indices = indices
            return new
        return Tensor(self.data[indices.data])
    
    def softmax(self):
        temp = np.exp(self.data)
        softmax_output = temp / np.sum(temp,
                                       axis=len(self.data.shape)-1,
                                       keepdims=True)
        return softmax_output
    
    def cross_entropy(self, target_indices):

        temp = np.exp(self.data)
        softmax_output = temp / np.sum(temp,
                                       axis=len(self.data.shape)-1,
                                       keepdims=True)
        
        t = target_indices.data.flatten()
        p = softmax_output.reshape(len(t),-1)
        target_dist = np.eye(p.shape[1])[t]
        loss = -(np.log(p) * (target_dist)).sum(1).mean()
    
        if(self.autograd):
            out = Tensor(loss,
                         autograd=True,
                         creators=[self],
                         creation_op="cross_entropy")
            out.softmax_output = softmax_output
            out.target_dist = target_dist
            return out

        return Tensor(loss)
        
    
    def __repr__(self):
        return str(self.data.__repr__())
    
    def __str__(self):
        return str(self.data.__str__())  

class Layer(object):
    
    def __init__(self):
        self.parameters = list()
        
    def get_parameters(self):
        return self.parameters

    
class SGD(object):
    
    def __init__(self, parameters, alpha=0.1):
        self.parameters = parameters
        self.alpha = alpha
    
    def zero(self):
        for p in self.parameters:
            p.grad.data *= 0
        
    def step(self, zero=True):
        
        for p in self.parameters:
            
            p.data -= p.grad.data * self.alpha
            
            if(zero):
                p.grad.data *= 0


class Linear(Layer):

    def __init__(self, n_inputs, n_outputs, bias=True):
        super().__init__()
        
        self.use_bias = bias
        
        W = np.random.randn(n_inputs, n_outputs) * np.sqrt(2.0/(n_inputs))
        self.weight = Tensor(W, autograd=True)
        if(self.use_bias):
            self.bias = Tensor(np.zeros(n_outputs), autograd=True)
        
        self.parameters.append(self.weight)
        
        if(self.use_bias):        
            self.parameters.append(self.bias)

    def forward(self, input):
        if(self.use_bias):
            return input.mm(self.weight)+self.bias.expand(0,len(input.data))
        return input.mm(self.weight)


class Sequential(Layer):
    
    def __init__(self, layers=list()):
        super().__init__()
        
        self.layers = layers
    
    def add(self, layer):
        self.layers.append(layer)
        
    def forward(self, input):
        for layer in self.layers:
            input = layer.forward(input)
        return input
    
    def get_parameters(self):
        params = list()
        for l in self.layers:
            params += l.get_parameters()
        return params


class Embedding(Layer):
    
    def __init__(self, vocab_size, dim):
        super().__init__()
        
        self.vocab_size = vocab_size
        self.dim = dim
        
        # this random initialiation style is just a convention from word2vec
        self.weight = Tensor((np.random.rand(vocab_size, dim) - 0.5) / dim, autograd=True)
        
        self.parameters.append(self.weight)
    
    def forward(self, input):
        return self.weight.index_select(input)


class Tanh(Layer):
    def __init__(self):
        super().__init__()
    
    def forward(self, input):
        return input.tanh()


class Sigmoid(Layer):
    def __init__(self):
        super().__init__()
    
    def forward(self, input):
        return input.sigmoid()
    

class CrossEntropyLoss(object):
    
    def __init__(self):
        super().__init__()
    
    def forward(self, input, target):
        return input.cross_entropy(target)

    
class RNNCell(Layer):
    
    def __init__(self, n_inputs, n_hidden, n_output, activation='sigmoid'):
        super().__init__()

        self.n_inputs = n_inputs
        self.n_hidden = n_hidden
        self.n_output = n_output
        
        if(activation == 'sigmoid'):
            self.activation = Sigmoid()
        elif(activation == 'tanh'):
            self.activation == Tanh()
        else:
            raise Exception("Non-linearity not found")

        self.w_ih = Linear(n_inputs, n_hidden)
        self.w_hh = Linear(n_hidden, n_hidden)
        self.w_ho = Linear(n_hidden, n_output)
        
        self.parameters += self.w_ih.get_parameters()
        self.parameters += self.w_hh.get_parameters()
        self.parameters += self.w_ho.get_parameters()        
    
    def forward(self, input, hidden):
        from_prev_hidden = self.w_hh.forward(hidden)
        combined = self.w_ih.forward(input) + from_prev_hidden
        new_hidden = self.activation.forward(combined)
        output = self.w_ho.forward(new_hidden)
        return output, new_hidden
    
    def init_hidden(self, batch_size=1):
        return Tensor(np.zeros((batch_size,self.n_hidden)), autograd=True)
    
class LSTMCell(Layer):
    
    def __init__(self, n_inputs, n_hidden, n_output):
        super().__init__()

        self.n_inputs = n_inputs
        self.n_hidden = n_hidden
        self.n_output = n_output

        self.xf = Linear(n_inputs, n_hidden)
        self.xi = Linear(n_inputs, n_hidden)
        self.xo = Linear(n_inputs, n_hidden)        
        self.xc = Linear(n_inputs, n_hidden)        
        
        self.hf = Linear(n_hidden, n_hidden, bias=False)
        self.hi = Linear(n_hidden, n_hidden, bias=False)
        self.ho = Linear(n_hidden, n_hidden, bias=False)
        self.hc = Linear(n_hidden, n_hidden, bias=False)        
        
        self.w_ho = Linear(n_hidden, n_output, bias=False)
        
        self.parameters += self.xf.get_parameters()
        self.parameters += self.xi.get_parameters()
        self.parameters += self.xo.get_parameters()
        self.parameters += self.xc.get_parameters()

        self.parameters += self.hf.get_parameters()
        self.parameters += self.hi.get_parameters()        
        self.parameters += self.ho.get_parameters()        
        self.parameters += self.hc.get_parameters()                
        
        self.parameters += self.w_ho.get_parameters()        
    
    def forward(self, input, hidden):
        
        prev_hidden = hidden[0]        
        prev_cell = hidden[1]
        
        f = (self.xf.forward(input) + self.hf.forward(prev_hidden)).sigmoid()
        i = (self.xi.forward(input) + self.hi.forward(prev_hidden)).sigmoid()
        o = (self.xo.forward(input) + self.ho.forward(prev_hidden)).sigmoid()        
        g = (self.xc.forward(input) + self.hc.forward(prev_hidden)).tanh()        
        c = (f * prev_cell) + (i * g)

        h = o * c.tanh()
        
        output = self.w_ho.forward(h)
        return output, (h, c)
    
    def init_hidden(self, batch_size=1):
        init_hidden = Tensor(np.zeros((batch_size,self.n_hidden)), autograd=True)
        init_cell = Tensor(np.zeros((batch_size,self.n_hidden)), autograd=True)
        init_hidden.data[:,0] += 1
        init_cell.data[:,0] += 1
        return (init_hidden, init_cell)

# %%
f = open('shakespear.txt', 'r')
raw = f.read()
f.close()

vocab = list(set(raw))
word2index = {}
for i, word in enumerate(vocab):
    word2index[word] = i
    
indices = np.array(list(map(lambda x:word2index[x], raw)))

# %%
embed = Embedding(vocab_size=len(vocab),dim=512)
model = RNNCell(n_inputs=512, n_hidden=512, n_output=len(vocab))

criterion = CrossEntropyLoss()
optim = SGD(parameters = model.get_parameters() + embed.get_parameters(), alpha = 0.05)

batch_size = 32 
bptt = 16 
n_batches = int((indices.shape[0] / (batch_size)))

trimmed_indices = indices[:n_batches*batch_size] 
batched_indices = trimmed_indices.reshape(batch_size, n_batches) 
batched_indices = batched_indices.transpose()

input_batched_indices = batched_indices[0:-1] 
target_batched_indices = batched_indices[1:]

n_bptt = int(((n_batches-1) / bptt)) 
input_batches = input_batched_indices[:n_bptt*bptt] 
input_batches = input_batches.reshape(n_bptt,bptt,batch_size) 
target_batches = target_batched_indices[:n_bptt*bptt] 
target_batches =  target_batches.reshape(n_bptt, bptt, batch_size)

# %%
import sys

def generate_sample(n=30, init_char=' '):
    s = ""
    hidden = model.init_hidden(batch_size=1)
    input = Tensor(np.array([word2index[init_char]]))
    for i in range(n):
        rnn_input = embed.forward(input)
        output, hidden = model.forward(input=rnn_input, hidden=hidden)
        m = output.data.argmax()
        c = vocab[m]
        input = Tensor(np.array([m]))
        s += c
    return s

def train(iterations=100):    
    for iter in range(iterations):        
        total_loss = 0        
        n_loss = 0
        hidden = model.init_hidden(batch_size=batch_size)
        
        for batch_i in range(len(input_batches)):
            hidden = Tensor(hidden.data, autograd=True)            
            loss = None            
            losses = list()            
            for t in range(bptt):                
                input = Tensor(input_batches[batch_i][t], autograd=True)                
                rnn_input = embed.forward(input=input)                
                output, hidden = model.forward(input=rnn_input, hidden=hidden)                
                target = Tensor(target_batches[batch_i][t], autograd=True)                    
                batch_loss = criterion.forward(output, target)                
                losses.append(batch_loss)                
                if(t == 0):                    
                    loss = batch_loss                
                else:                    
                    loss = loss + batch_loss            
            for loss in losses:                
                ""            
            loss.backward()            
            optim.step()            
            total_loss += loss.data            
            
            log = "\r Iter:" + str(iter)            
            log += " - Batch "+str(batch_i+1)+"/"+str(len(input_batches))            
            log += " - Loss:" + str(np.exp(total_loss / (batch_i+1)))            
            if(batch_i == 0):                
                log += " - " + generate_sample(70,'\n').replace("\n"," ")            
            if(batch_i % 10 == 0 or batch_i-1 == len(input_batches)):                
                sys.stdout.write(log)        
        optim.alpha *= 0.99        
        print()

# %%
train()
# Out:
#  Iter:0 - Batch 191/195 - Loss:50.497742589356314tttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttt
#
#  Iter:1 - Batch 191/195 - Loss:16.908823505399635 ot the thet the thet the thet the thet the thet the thet the thet the
#
#  Iter:2 - Batch 191/195 - Loss:13.559755677333275 the the the the the the the the the the the the the the the the the
#
#  Iter:3 - Batch 191/195 - Loss:12.089475862346315h the the the the the the the the the the the the the the the the the
#
#  Iter:4 - Batch 191/195 - Loss:11.172972127853823h the the the the the the the the the the the the the the the the the
#
#  Iter:5 - Batch 191/195 - Loss:10.461621027246224ha the the the the the the the the the the the the the the the the the
#
#  Iter:6 - Batch 191/195 - Loss:9.8730588796560987ha the the the the the the the the the the the the the the the the the
#
#  Iter:7 - Batch 191/195 - Loss:9.368783752113966 CI with the the the the the the the the the the the the the the the th
#
#  Iter:8 - Batch 191/195 - Loss:8.925633690937444 CE wo the the the the the the the the the the the the the the the the
#
#  Iter:9 - Batch 191/195 - Loss:8.532044361731735- CE I with the the the the the the the the the the the the the the the
#
#  Iter:10 - Batch 191/195 - Loss:8.183319841602925 CE I with the the the the the the the the the the the the the the the
#
#  Iter:11 - Batch 191/195 - Loss:7.8716218982647375 I with the the the the the the the the the the the the the the the
#
#  Iter:12 - Batch 191/195 - Loss:7.5894348996372155CE HE I with the the the the the the the the the the the the the the t
#
#  Iter:13 - Batch 191/195 - Loss:7.3308856452775995E HES: I with the the the the the the the the the the the the the the
#
#  Iter:14 - Batch 191/195 - Loss:7.091354216484573 ME HES: I with the the the the the the the the the the the the the the
#
#  Iter:15 - Batch 191/195 - Loss:6.8661180812346535ME HES: I with the the the the the the the the the the the the the the
#
#  Iter:16 - Batch 191/195 - Loss:6.6513654895787455ME HESThing the the the the the the the the the the the the the the th
#
#  Iter:17 - Batch 191/195 - Loss:6.4430270463450375MA prace the the the the the the the the the the the the the the the t
#
#  Iter:18 - Batch 191/195 - Loss:6.238944529785513 MA prace the to to the to to the to to the to to the to to the to to t
#
#  Iter:19 - Batch 191/195 - Loss:6.038913818045611 MA prace to the to to the to to the to to the to to the to to the to t
#
#  Iter:20 - Batch 191/195 - Loss:5.8435568778581485MA prearst the to the to to the to to the to to the to to the to to th
#
#  Iter:21 - Batch 191/195 - Loss:5.6521489212759565MA prearses, sirst the to the to the to the to the to the to the to th
#
#  Iter:22 - Batch 191/195 - Loss:5.463697923884632MALIUS: Hay, sirst the to the to the to the to the to the to the to th
#
#  Iter:23 - Batch 191/195 - Loss:5.2788609653086075MALIUS: Hay, sirst the to the to the to the to the to the to the to th
#
#  Iter:24 - Batch 191/195 - Loss:5.097666453568218 MALIUS: He to the to the to the to the to the to the to the to the to
#
#  Iter:25 - Batch 191/195 - Loss:4.9184347200345325MALIUS: He to the to the to the to the to the to the to the to the to
#
#  Iter:26 - Batch 191/195 - Loss:4.7398206226622175MALIUS: He to the to the to the to the to the to the to the to the to
#
#  Iter:27 - Batch 191/195 - Loss:4.5630512889107075 MALIUS: He to the sammon the sammon the sammon the sammon the sammon t
#
#  Iter:28 - Batch 191/195 - Loss:4.390029621693156 MALIUS: He to the sammon to the to the sammon to the to the sammon to
#
#  Iter:29 - Batch 191/195 - Loss:4.2209173710846915I would himsed to the sammon to the to the sammon to the to the sammo
#
#  Iter:30 - Batch 191/195 - Loss:4.0553163243796944MI would himsed to the sammon to the to the to the to the to the to th
#
#  Iter:31 - Batch 191/195 - Loss:3.8936691508384857 MI would himsed himser are are are are are are are are are are are are
#
#  Iter:32 - Batch 191/195 - Loss:3.7375291018432835 MI would himsed himser are are are are are are are are are are are are
#
#  Iter:33 - Batch 191/195 - Loss:3.5850333124827927 MI would himser are would himsed himser are would himsed himser are wo
#
#  Iter:34 - Batch 191/195 - Loss:3.4363197149463195 MI would himser are would himser are would himser are would himser are
#
#  Iter:35 - Batch 191/195 - Loss:3.2911964469596256MI would himser are would himser are would himser are would himser are
#
#  Iter:36 - Batch 191/195 - Loss:3.1487983956399908I would himser are would himser are would himser are would himser are
#
#  Iter:37 - Batch 191/195 - Loss:3.0099946597698725 MI would himser are would himser are would himser are would himser are
#
#  Iter:38 - Batch 191/195 - Loss:2.8759574575548608MI would himsers, to the tamnters to the tainted hath staints, and hat
#
#  Iter:39 - Batch 191/195 - Loss:2.7461007993423336 MI would himsers, to the tainted himsed himsed himsed himsed himsed hi
#
#  Iter:40 - Batch 191/195 - Loss:2.6220818476916983MI would himsers, this staints, and hath staints, and hath staints, an
#
#  Iter:41 - Batch 191/195 - Loss:2.5056126246733363 MAy, sith to the tainted himsed himsed himsed himsed himsed himsed him
#
#  Iter:42 - Batch 191/195 - Loss:2.3953115596772157 MAy, sith to the tainted himsed himsed himsed himsed himsed himsed him
#
#  Iter:43 - Batch 191/195 - Loss:2.2892921532694177MAy, sith to the tamnters sinonould have the tainted himsed himsed him
#
#  Iter:44 - Batch 191/195 - Loss:2.1893844554676405MI would himsers, this staints, this staints, this staints, this stain
#
#  Iter:45 - Batch 191/195 - Loss:2.0913439277543793 MAy, sith to the tamnters speakes, this stair: the tamnters speakes, t
#
#  Iter:46 - Batch 191/195 - Loss:2.0003195564208096 MAy, sith to the tamnters speakes, this stair: the tamnters speakes, t
#
#  Iter:47 - Batch 191/195 - Loss:1.9162356470653004 MAy, sich this stair: the tamnters speakes to the tamnters speakes to
#
#  Iter:48 - Batch 191/195 - Loss:1.8363379191940685MAy, sich this stair: the tamnters speakes to this stair: the tamnters
#
#  Iter:49 - Batch 191/195 - Loss:1.7620913227106965 MAy, sink restrun makes: He monered my hath sath himsers, thin this st
#
#  Iter:50 - Batch 191/195 - Loss:1.6931621028765902 MAy, sink rguther: thin this stod But this stodlements, thin this stod
#
#  Iter:51 - Batch 191/195 - Loss:1.6318349420790434 MAy, sink rguther: things, and himser him the makes and himser him the
#
#  Iter:52 - Batch 191/195 - Loss:1.5821520832560255 MAy, sink rguther: think our would have from the makes and him, To my
#
#  Iter:53 - Batch 191/195 - Loss:1.5344884749412344 MAy, sind him, To my hath sath himser are whill or him, To my hath sat
#
#  Iter:54 - Batch 191/195 - Loss:1.4860506219646237 MAy, sing ont? this stod But this stod But this stod But this stod But
#
#  Iter:55 - Batch 191/195 - Loss:1.4468625810408097 MAy, sing ont? this stod But thin this stod But thin this stod But thi
#
#  Iter:56 - Batch 191/195 - Loss:1.4079969195092965 MAy, sing ont?  MALVENS: Which thin this stod But this stod But this s
#
#  Iter:57 - Batch 191/195 - Loss:1.3656632725270805 MAy, sind him, This stod But thin this stod But thin this stod But thi
#
#  Iter:58 - Batch 191/195 - Loss:1.3401209962998353 MAy, sing ont?  MALVENS: Which this tamnters hoth so find a facerfair:
#
#  Iter:59 - Batch 191/195 - Loss:1.3022945628884206 MAy, sing ont?  MALCENS: Which this stod But think a facersevery and h
#
#  Iter:60 - Batch 191/195 - Loss:1.2767216716994312MAy, sind him, This stod the man's and him, This stod the man's and hi
#
#  Iter:61 - Batch 191/195 - Loss:1.2509848014831897 MAy, sing of this stod But things, and him, This stod But things, and
#
#  Iter:62 - Batch 191/195 - Loss:1.2490751154002873 MAy, sing of thy thin the man's and him, This stod But this stod But t
#
#  Iter:63 - Batch 191/195 - Loss:1.2612300866479758 MAy, sing from the man's and may, hath so find a facersevery and may,
#
#  Iter:64 - Batch 191/195 - Loss:1.2336227636259995 MAy, sing offingur brow the man's and samines all or have no viitstakn
#
#  Iter:65 - Batch 191/195 - Loss:1.2407108606042154 MAys for which this stod the man's and eatsess of thy all the man's an
#
#  Iter:66 - Batch 191/195 - Loss:1.1855734124305149 MAy, sing firsed him the man's and him, This stortherchain the man's a
#
#  Iter:67 - Batch 191/195 - Loss:1.1605279093807017MAy, sing of thy all or him, That stent him, This stoding sath this st
#
#  Iter:68 - Batch 191/195 - Loss:1.1457889812064328 MAy, sing firsed him the man's and eat, Sot make him, That camines a s
#
#  Iter:69 - Batch 191/195 - Loss:1.1304007713239111 MAystalk the man's as the man's and eat, Sot make him, This stod my sa
#
#  Iter:70 - Batch 191/195 - Loss:1.1190561115120263 MALpace.  CAESTI cammonis tamn; with a spare neakes this stortherchain
#
#  Iter:71 - Batch 191/195 - Loss:1.1098949376526395 MALpace.  CAESTI cammonir have neaket, that campon my sake thy all thi
#
#  Iter:72 - Batch 191/195 - Loss:1.0990955679546313 MALpace.  CAESTI cammonis tamn; with a day?  Secongue, To mn the man's
#
#  Iter:73 - Batch 191/195 - Loss:1.0911827561915257 MALpace.  CAESTI conflient the that your commy at the maness. the man'
#
#  Iter:74 - Batch 191/195 - Loss:1.0839566650034476MALpaLIAn: The maness. not? Yor.  CHESTI conflient the that I would ne
#
#  Iter:75 - Batch 191/195 - Loss:1.0784507475043892 MALpaLIAn: The maness. not? Yor.  CHESTI compon in thy ting firsed and
#
#  Iter:76 - Batch 191/195 - Loss:1.0732005722700222 MALpaLIAn: swee tore justoriose, Too darrouslay? hounder allains: Hay,
#
#  Iter:77 - Batch 191/195 - Loss:1.0673642890604391 MALpaLIAn: Thish a spall or the man's this sequet my his ithill or the
#
#  Iter:78 - Batch 191/195 - Loss:1.0629880661062493 MALpaLIAn: swee tore justoriose, Too darrouslay? hounder allains: Hay,
#
#  Iter:79 - Batch 191/195 - Loss:1.0588520436112425MALpaLIAn: swee tore he kars?  ANGIPIN: she was nould new, hath not un
#
#  Iter:80 - Batch 191/195 - Loss:1.0551470603621536 Mecting sath the man's as came of this? have he wassadver and sworld s
#
#  Iter:81 - Batch 191/195 - Loss:1.0518722698317176 Mecting sath the man's as came of this? have he wassadver and from the
#
#  Iter:82 - Batch 191/195 - Loss:1.0489087445457763 Mectiflir by the man's as came of this? have he wassadver and from the
#
#  Iter:83 - Batch 191/195 - Loss:1.0462390274726117 Mectiflir by the man's as came of this? have he wassadver and from the
#
#  Iter:84 - Batch 191/195 - Loss:1.0437713940882227 Mectiflir by the conforther the nitself the man's as came of this? hav
#
#  Iter:85 - Batch 191/195 - Loss:1.0416802384158228 Mectiflir by the conforther the nitself the man's as came thuck with h
#
#  Iter:86 - Batch 191/195 - Loss:1.0395536568358683 Mectiflir by the conforther the nitself the man's as came thuck with h
#
#  Iter:87 - Batch 191/195 - Loss:1.0378851463600443 Mectiflir by the conforther the nitself the man's as came thuck with h
#
#  Iter:88 - Batch 191/195 - Loss:1.0361055394262322 Mectifled his desing from the man's as came thuck with her, The day?
#
#  Iter:89 - Batch 191/195 - Loss:1.0347780877206418 Mectifled his desing from the man's as cumines a speat, Sot mave his d
#
#  Iter:90 - Batch 191/195 - Loss:1.0333287644394022 Mectifled his desing from the mant his desine allainst, prevery steeds
#
#  Iter:91 - Batch 191/195 - Loss:1.0323943171170795Mectifled his desing from the mant his desine allainst, prevery steeds
#
#  Iter:92 - Batch 191/195 - Loss:1.0316694819734438 Mectifled his desing from the mant his desine allainst, prevery steeds
#
#  Iter:93 - Batch 191/195 - Loss:1.0304863969302058 Mectifled his desing from the mant his desine allainst, prevery steeds
#
#  Iter:94 - Batch 191/195 - Loss:1.0289158349575631 Mectifled his desing from the mant here The day?  Seconflient the the
#
#  Iter:95 - Batch 191/195 - Loss:1.0277305538430315 Mectifled his desing from the mant here of this? have his desine allai
#
#  Iter:96 - Batch 191/195 - Loss:1.0267425343423546 Mectifled his desing from the mant here of this? have his desine allai
#
#  Iter:97 - Batch 191/195 - Loss:1.0258309790248554 Mectifled his desing from the mant here of this? have his desine allai
#
#  Iter:98 - Batch 191/195 - Loss:1.0249786749424814 Mectifled his desing from the mant here of this? have his desine allai
#
#  Iter:99 - Batch 191/195 - Loss:1.0241914446881013 Mectifled his desing from the mant here of this? have his desine allai

# %%
f = open('shakespear.txt', 'r')
raw = f.read()
f.close()

vocab = list(set(raw))
word2index = {}
for i, word in enumerate(vocab):
    word2index[word] = i
indices = np.array(list(map(lambda x:word2index[x], raw)))

embed = Embedding(vocab_size = len(vocab), dim = 512)
model = LSTMCell(n_inputs = 512, n_hidden = 512, n_output = len(vocab))
model.w_ho.weight.data *= 0

criterion = CrossEntropyLoss()
optim = SGD(parameters = model.get_parameters() + embed.get_parameters(),
           alpha = 0.05)

# %%
batch_size = 16
bptt = 32
n_batches = int((indices.shape[0] / batch_size))

trimmed_indices = indices[:n_batches*batch_size]
batched_indices = trimmed_indices.reshape(batch_size, n_batches)
batched_indices = batched_indices.transpose()

input_batched_indices = batched_indices[0:-1]
target_batched_indices = batched_indices[1:]

n_bptt = int(((n_batches - 1) / bptt))
input_batches = input_batched_indices[:n_bptt*bptt]
input_batches = input_batches.reshape(n_bptt, bptt, batch_size)
target_batches = target_batched_indices[:n_bptt*bptt]
target_batches = target_batches.reshape(n_bptt, bptt, batch_size)
min_loss = 1000

# %%
def generate_sample(n=30, init_char=' '):    
    s = ""    
    hidden = model.init_hidden(batch_size=1)    
    input = Tensor(np.array([word2index[init_char]]))    
    for i in range(n):        
        rnn_input = embed.forward(input)        
        output, hidden = model.forward(input=rnn_input, hidden=hidden)        
        output.data *= 15        
        temp_dist = output.softmax()        
        temp_dist /= temp_dist.sum()
        
        m = output.data.argmax()         
        c = vocab[m]        
        input = Tensor(np.array([m]))        
        s += c    
    return s 

def lstmTrain(iterations = 100):
    global min_loss
    
    for iter in range(iterations):
        total_loss = 0
        n_loss = 0

        hidden = model.init_hidden(batch_size=batch_size)
        batches_to_train = len(input_batches)
        for batch_i in range(batches_to_train):

            hidden = (Tensor(hidden[0].data, autograd=True), Tensor(hidden[1].data, autograd=True))

            losses = list()
            for t in range(bptt):
                input = Tensor(input_batches[batch_i][t], autograd=True)
                rnn_input = embed.forward(input=input)
                output, hidden = model.forward(input=rnn_input, hidden=hidden)

                target = Tensor(target_batches[batch_i][t], autograd=True)    
                batch_loss = criterion.forward(output, target)

                if(t == 0):
                    losses.append(batch_loss)
                else:
                    losses.append(batch_loss + losses[-1])

            loss = losses[-1]

            loss.backward()
            optim.step()
            total_loss += loss.data / bptt

            epoch_loss = np.exp(total_loss / (batch_i+1))
            if(epoch_loss < min_loss):
                min_loss = epoch_loss
                print()

            log = "\r Iter:" + str(iter)
            log += " - Alpha:" + str(optim.alpha)[0:5]
            log += " - Batch "+str(batch_i+1)+"/"+str(len(input_batches))
            log += " - Min Loss:" + str(min_loss)[0:5]
            log += " - Loss:" + str(epoch_loss)
            if(batch_i == 0):
                log += " - " + generate_sample(n=70, init_char='T').replace("\n"," ")
            if(batch_i % 1 == 0):
                sys.stdout.write(log)
        optim.alpha *= 0.99

# %%
lstmTrain()
# Out:
#  Iter:0 - Alpha:0.05 - Batch 1/195 - Min Loss:60.56 - Loss:60.56878463062831 -
#  Iter:0 - Alpha:0.05 - Batch 2/195 - Min Loss:60.26 - Loss:60.262762506580685
#  Iter:0 - Alpha:0.05 - Batch 3/195 - Min Loss:59.25 - Loss:59.251142502992984
#  Iter:0 - Alpha:0.05 - Batch 4/195 - Min Loss:56.68 - Loss:56.686786087541414
#  Iter:0 - Alpha:0.05 - Batch 5/195 - Min Loss:52.53 - Loss:52.532575001492134
#  Iter:0 - Alpha:0.05 - Batch 6/195 - Min Loss:48.71 - Loss:48.71750593449273
#  Iter:0 - Alpha:0.05 - Batch 7/195 - Min Loss:44.61 - Loss:44.61643862497596
#  Iter:0 - Alpha:0.05 - Batch 8/195 - Min Loss:43.30 - Loss:43.3011460802399
#  Iter:0 - Alpha:0.05 - Batch 9/195 - Min Loss:42.11 - Loss:42.116037101673584
#  Iter:0 - Alpha:0.05 - Batch 11/195 - Min Loss:40.24 - Loss:40.35130014103254
#  Iter:0 - Alpha:0.05 - Batch 12/195 - Min Loss:39.36 - Loss:39.365915350404066
#  Iter:0 - Alpha:0.05 - Batch 13/195 - Min Loss:38.84 - Loss:38.845846993982626
#  Iter:0 - Alpha:0.05 - Batch 14/195 - Min Loss:38.14 - Loss:38.14795434396516
#  Iter:0 - Alpha:0.05 - Batch 15/195 - Min Loss:38.06 - Loss:38.06390816648567
