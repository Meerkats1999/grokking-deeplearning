# %% [markdown]
# Upgrading the MNIST Network

# %%
import numpy as np
from keras.datasets import mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()
images, labels = (x_train[0:1000].reshape(1000, 28*28)/255, y_train[0:1000])

one_hot_labels = np.zeros((len(labels), 10))
for i, l in enumerate(labels):
    one_hot_labels[i][l] = 1
labels = one_hot_labels

test_images = x_test.reshape(len(x_test), 28*28)/255
test_labels = np.zeros((len(y_test), 10))
for i, l in enumerate(y_test):
    test_labels[i][l] = 1
    
def tanh(x):
    return np.tanh(x)

def tanh2deriv(output):
    return (1 - (output ** 2))

def softmax(x):
    temp = np.exp(x)
    return temp/np.sum(temp, axis=1, keepdims = True)
# Out:
# Using TensorFlow backend.

# %%
np.random.seed(1)

alpha = 0.001
iterations = 100
hidden_size = 100
pixels_per_image = 784
num_labels = 10

weights_0 = 0.2*np.random.random((pixels_per_image, hidden_size)) - 0.1
weights_1 = 0.2*np.random.random((hidden_size, num_labels)) - 0.1

batch_size = 100

for j in range(iterations):
    error = 0
    correct_cnt = 0
    test_err = 0
    test_correct_cnt = 0
    
    for i in range(int(len(images) / batch_size)):
        batch_start, batch_end = ((i * batch_size), ((i+1) * batch_size))
        
        layer_0 = images[batch_start:batch_end]
        layer_1 = tanh(np.dot(layer_0, weights_0))
        dropout = np.random.randint(2, size = layer_1.shape)
        layer_1 = layer_1 * dropout
        layer_2 = softmax(np.dot(layer_1, weights_1))
        
        error += np.sum((labels[batch_start:batch_end] - layer_2) ** 2)
        for k in range(batch_size):
            correct_cnt = int(np.argmax(layer_2[k:k+1]) == np.argmax(labels[batch_start+k:batch_start+k+1]))
            
            layer_2_delta = (labels[batch_start:batch_end] - layer_2)/batch_size
            layer_1_delta = layer_2_delta.dot(weights_1.T) * tanh2deriv(layer_1)
            layer_1_delta = layer_1_delta * dropout
            
            weights_1 += alpha * layer_1.T.dot(layer_2_delta)
            weights_0 += alpha * layer_0.T.dot(layer_1_delta)
        
        
    for i in range(len(test_images)):
        layer_0 = test_images[i:i+1]
        layer_1 = tanh(np.dot(layer_0, weights_0))
        layer_2 = np.dot(layer_1, weights_1)
        
        test_err += np.sum((test_labels[i:i+1] - layer_2) ** 2)
        test_correct_cnt += int(np.argmax(layer_2) == np.argmax(test_labels[i:i+1]))
            
    print("Iteration: "+str(j))
    print("Train-Err: "+str(error/float(len(images)))[0:5])
    print("Train-Accuracy: "+str(correct_cnt/float(len(images))))
    print("Test-Accuracy: "+str((test_correct_cnt/float(len(images)))/10))
    print("---------------------")
# Out:
# Iteration: 0
# Train-Err: 0.892
# Train-Accuracy: 0.0
# Test-Accuracy: 0.37839999999999996
# ---------------------
# Iteration: 1
# Train-Err: 0.863
# Train-Accuracy: 0.0
# Test-Accuracy: 0.576
# ---------------------
# Iteration: 2
# Train-Err: 0.830
# Train-Accuracy: 0.0
# Test-Accuracy: 0.6388
# ---------------------
# Iteration: 3
# Train-Err: 0.791
# Train-Accuracy: 0.0
# Test-Accuracy: 0.6618999999999999
# ---------------------
# Iteration: 4
# Train-Err: 0.750
# Train-Accuracy: 0.001
# Test-Accuracy: 0.6759000000000001
# ---------------------
# Iteration: 5
# Train-Err: 0.705
# Train-Accuracy: 0.0
# Test-Accuracy: 0.6860999999999999
# ---------------------
# Iteration: 6
# Train-Err: 0.655
# Train-Accuracy: 0.0
# Test-Accuracy: 0.6987
# ---------------------
# Iteration: 7
# Train-Err: 0.603
# Train-Accuracy: 0.001
# Test-Accuracy: 0.7055
# ---------------------
# Iteration: 8
# Train-Err: 0.562
# Train-Accuracy: 0.001
# Test-Accuracy: 0.7171000000000001
# ---------------------
# Iteration: 9
# Train-Err: 0.524
# Train-Accuracy: 0.001
# Test-Accuracy: 0.7285999999999999
# ---------------------
# Iteration: 10
# Train-Err: 0.486
# Train-Accuracy: 0.0
# Test-Accuracy: 0.7403
# ---------------------
# Iteration: 11
# Train-Err: 0.459
# Train-Accuracy: 0.001
# Test-Accuracy: 0.749
# ---------------------
# Iteration: 12
# Train-Err: 0.425
# Train-Accuracy: 0.001
# Test-Accuracy: 0.7603
# ---------------------
# Iteration: 13
# Train-Err: 0.405
# Train-Accuracy: 0.001
# Test-Accuracy: 0.769
# ---------------------
# Iteration: 14
# Train-Err: 0.390
# Train-Accuracy: 0.001
# Test-Accuracy: 0.7762
# ---------------------
# Iteration: 15
# Train-Err: 0.365
# Train-Accuracy: 0.001
# Test-Accuracy: 0.7825
# ---------------------
# Iteration: 16
# Train-Err: 0.352
# Train-Accuracy: 0.001
# Test-Accuracy: 0.7877
# ---------------------
# Iteration: 17
# Train-Err: 0.337
# Train-Accuracy: 0.001
# Test-Accuracy: 0.7942
# ---------------------
# Iteration: 18
# Train-Err: 0.325
# Train-Accuracy: 0.001
# Test-Accuracy: 0.7996000000000001
# ---------------------
# Iteration: 19
# Train-Err: 0.311
# Train-Accuracy: 0.001
# Test-Accuracy: 0.805
# ---------------------
# Iteration: 20
# Train-Err: 0.298
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8097
# ---------------------
# Iteration: 21
# Train-Err: 0.290
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8129
# ---------------------
# Iteration: 22
# Train-Err: 0.280
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8137000000000001
# ---------------------
# Iteration: 23
# Train-Err: 0.267
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8180999999999999
# ---------------------
# Iteration: 24
# Train-Err: 0.255
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8201
# ---------------------
# Iteration: 25
# Train-Err: 0.252
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8220000000000001
# ---------------------
# Iteration: 26
# Train-Err: 0.246
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8276999999999999
# ---------------------
# Iteration: 27
# Train-Err: 0.233
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8301000000000001
# ---------------------
# Iteration: 28
# Train-Err: 0.234
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8313
# ---------------------
# Iteration: 29
# Train-Err: 0.225
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8337
# ---------------------
# Iteration: 30
# Train-Err: 0.223
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8339000000000001
# ---------------------
# Iteration: 31
# Train-Err: 0.214
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8353999999999999
# ---------------------
# Iteration: 32
# Train-Err: 0.214
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8371999999999999
# ---------------------
# Iteration: 33
# Train-Err: 0.207
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8385999999999999
# ---------------------
# Iteration: 34
# Train-Err: 0.197
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8393
# ---------------------
# Iteration: 35
# Train-Err: 0.197
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8422000000000001
# ---------------------
# Iteration: 36
# Train-Err: 0.192
# Train-Accuracy: 0.001
# Test-Accuracy: 0.844
# ---------------------
# Iteration: 37
# Train-Err: 0.192
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8446
# ---------------------
# Iteration: 38
# Train-Err: 0.192
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8469
# ---------------------
# Iteration: 39
# Train-Err: 0.184
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8491
# ---------------------
# Iteration: 40
# Train-Err: 0.176
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8499000000000001
# ---------------------
# Iteration: 41
# Train-Err: 0.182
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8494999999999999
# ---------------------
# Iteration: 42
# Train-Err: 0.172
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8493999999999999
# ---------------------
# Iteration: 43
# Train-Err: 0.170
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8507
# ---------------------
# Iteration: 44
# Train-Err: 0.167
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8516
# ---------------------
# Iteration: 45
# Train-Err: 0.165
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8525
# ---------------------
# Iteration: 46
# Train-Err: 0.157
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8547
# ---------------------
# Iteration: 47
# Train-Err: 0.158
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8549
# ---------------------
# Iteration: 48
# Train-Err: 0.154
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8548
# ---------------------
# Iteration: 49
# Train-Err: 0.158
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8552
# ---------------------
# Iteration: 50
# Train-Err: 0.154
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8571
# ---------------------
# Iteration: 51
# Train-Err: 0.152
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8573000000000001
# ---------------------
# Iteration: 52
# Train-Err: 0.150
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8583999999999999
# ---------------------
# Iteration: 53
# Train-Err: 0.147
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8602000000000001
# ---------------------
# Iteration: 54
# Train-Err: 0.144
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8596
# ---------------------
# Iteration: 55
# Train-Err: 0.134
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8614
# ---------------------
# Iteration: 56
# Train-Err: 0.143
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8619
# ---------------------
# Iteration: 57
# Train-Err: 0.137
# Train-Accuracy: 0.001
# Test-Accuracy: 0.861
# ---------------------
# Iteration: 58
# Train-Err: 0.139
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8619
# ---------------------
# Iteration: 59
# Train-Err: 0.135
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8619
# ---------------------
# Iteration: 60
# Train-Err: 0.130
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8640000000000001
# ---------------------
# Iteration: 61
# Train-Err: 0.133
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8644000000000001
# ---------------------
# Iteration: 62
# Train-Err: 0.129
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8637
# ---------------------
# Iteration: 63
# Train-Err: 0.127
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8644000000000001
# ---------------------
# Iteration: 64
# Train-Err: 0.129
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8638
# ---------------------
# Iteration: 65
# Train-Err: 0.122
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8635999999999999
# ---------------------
# Iteration: 66
# Train-Err: 0.117
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8640000000000001
# ---------------------
# Iteration: 67
# Train-Err: 0.120
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8653000000000001
# ---------------------
# Iteration: 68
# Train-Err: 0.117
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8644999999999999
# ---------------------
# Iteration: 69
# Train-Err: 0.119
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8662000000000001
# ---------------------
# Iteration: 70
# Train-Err: 0.117
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8671
# ---------------------
# Iteration: 71
# Train-Err: 0.116
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8654999999999999
# ---------------------
# Iteration: 72
# Train-Err: 0.111
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8663000000000001
# ---------------------
# Iteration: 73
# Train-Err: 0.116
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8659000000000001
# ---------------------
# Iteration: 74
# Train-Err: 0.111
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8664999999999999
# ---------------------
# Iteration: 75
# Train-Err: 0.108
# Train-Accuracy: 0.001
# Test-Accuracy: 0.866
# ---------------------
# Iteration: 76
# Train-Err: 0.108
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8663000000000001
# ---------------------
# Iteration: 77
# Train-Err: 0.106
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8675
# ---------------------
# Iteration: 78
# Train-Err: 0.107
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8667999999999999
# ---------------------
# Iteration: 79
# Train-Err: 0.109
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8674
# ---------------------
# Iteration: 80
# Train-Err: 0.109
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8676999999999999
# ---------------------
# Iteration: 81
# Train-Err: 0.107
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8672000000000001
# ---------------------
# Iteration: 82
# Train-Err: 0.104
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8676
# ---------------------
# Iteration: 83
# Train-Err: 0.101
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8679
# ---------------------
# Iteration: 84
# Train-Err: 0.100
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8683
# ---------------------
# Iteration: 85
# Train-Err: 0.100
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8678000000000001
# ---------------------
# Iteration: 86
# Train-Err: 0.099
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8674
# ---------------------
# Iteration: 87
# Train-Err: 0.094
# Train-Accuracy: 0.001
# Test-Accuracy: 0.868
# ---------------------
# Iteration: 88
# Train-Err: 0.101
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8686999999999999
# ---------------------
# Iteration: 89
# Train-Err: 0.095
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8693
# ---------------------
# Iteration: 90
# Train-Err: 0.094
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8692
# ---------------------
# Iteration: 91
# Train-Err: 0.093
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8692
# ---------------------
# Iteration: 92
# Train-Err: 0.089
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8695999999999999
# ---------------------
# Iteration: 93
# Train-Err: 0.092
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8691000000000001
# ---------------------
# Iteration: 94
# Train-Err: 0.092
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8691000000000001
# ---------------------
# Iteration: 95
# Train-Err: 0.090
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8688
# ---------------------
# Iteration: 96
# Train-Err: 0.084
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8708
# ---------------------
# Iteration: 97
# Train-Err: 0.088
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8702
# ---------------------
# Iteration: 98
# Train-Err: 0.092
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8703
# ---------------------
# Iteration: 99
# Train-Err: 0.082
# Train-Accuracy: 0.001
# Test-Accuracy: 0.8709
# ---------------------
