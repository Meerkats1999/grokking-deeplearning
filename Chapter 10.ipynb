# %%
import numpy as np
from keras.datasets import mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()

images, labels = (x_train[0:1000].reshape(1000, 28*28), y_train[0:1000])

one_hot_labels = np.zeros((len(labels), 10))
for i, l in enumerate(labels):
    one_hot_labels[i][l] = 1
labels = one_hot_labels

test_images = x_test.reshape(len(x_test), 28*28)/255
test_labels = np.zeros((len(y_test), 10))
for i, l in enumerate(y_test):
    test_labels[i][l] = 1
    
def tanh(x):
    return np.tanh(x)

def tanh2deriv(output):
    return 1 - (output ** 2)

def softmax(x):
    temp = np.exp(x)
    return temp/np.sum(temp, axis=1, keepdims=True)

def get_image_section(layer, row_from, row_to, col_from, col_to):
    section = layer[:, row_from:row_to, col_from:col_to]
    return section.reshape(-1, 1, row_to-row_from, col_to-col_from)
# Out:
# Using TensorFlow backend.

# %%
np.random.seed(1)

alpha = 2
iterations = 100
pixels_per_image = 784
num_labels = 10
batch_size = 100

input_rows, input_cols = 28, 28
kernel_rows, kernel_cols = 3, 3
num_kernels = 16

hidden_size = ((input_rows - kernel_rows) * (input_cols - kernel_cols)) * num_kernels

kernels = 0.02*np.random.random((kernel_rows*kernel_cols, num_kernels)) - 0.01

weights_1_2 = 0.2*np.random.random((hidden_size,
                                    num_labels)) - 0.1

for j in range(iterations):
    correct_cnt = 0
    for i in range(int(len(images) / batch_size)):
        batch_start, batch_end=((i * batch_size),((i+1)*batch_size))
        layer_0 = images[batch_start:batch_end]
        layer_0 = layer_0.reshape(layer_0.shape[0],28,28)
        layer_0.shape

        sects = list()
        for row_start in range(layer_0.shape[1]-kernel_rows):
            for col_start in range(layer_0.shape[2] - kernel_cols):
                sect = get_image_section(layer_0,
                                         row_start,
                                         row_start+kernel_rows,
                                         col_start,
                                         col_start+kernel_cols)
                sects.append(sect)

        expanded_input = np.concatenate(sects,axis=1)
        es = expanded_input.shape
        flattened_input = expanded_input.reshape(es[0]*es[1],-1)

        kernel_output = flattened_input.dot(kernels)
        layer_1 = tanh(kernel_output.reshape(es[0],-1))
        dropout_mask = np.random.randint(2,size=layer_1.shape)
        layer_1 *= dropout_mask * 2
        layer_2 = softmax(np.dot(layer_1,weights_1_2))

        for k in range(batch_size):
            labelset = labels[batch_start+k:batch_start+k+1]
            _inc = int(np.argmax(layer_2[k:k+1]) == 
                               np.argmax(labelset))
            correct_cnt += _inc

        layer_2_delta = (labels[batch_start:batch_end]-layer_2)\
                        / (batch_size * layer_2.shape[0])
        layer_1_delta = layer_2_delta.dot(weights_1_2.T) * \
                        tanh2deriv(layer_1)
        layer_1_delta *= dropout_mask
        weights_1_2 += alpha * layer_1.T.dot(layer_2_delta)
        l1d_reshape = layer_1_delta.reshape(kernel_output.shape)
        k_update = flattened_input.T.dot(l1d_reshape)
        kernels -= alpha * k_update
    
    test_correct_cnt = 0

    for i in range(len(test_images)):

        layer_0 = test_images[i:i+1]
        layer_0 = layer_0.reshape(layer_0.shape[0],28,28)
        layer_0.shape

        sects = list()
        for row_start in range(layer_0.shape[1]-kernel_rows):
            for col_start in range(layer_0.shape[2] - kernel_cols):
                sect = get_image_section(layer_0,
                                         row_start,
                                         row_start+kernel_rows,
                                         col_start,
                                         col_start+kernel_cols)
                sects.append(sect)

        expanded_input = np.concatenate(sects,axis=1)
        es = expanded_input.shape
        flattened_input = expanded_input.reshape(es[0]*es[1],-1)

        kernel_output = flattened_input.dot(kernels)
        layer_1 = tanh(kernel_output.reshape(es[0],-1))
        layer_2 = np.dot(layer_1,weights_1_2)

        test_correct_cnt += int(np.argmax(layer_2) == 
                                np.argmax(test_labels[i:i+1]))
        
    print("Iteration: "+str(j+1))
    print("Train-Accuracy: "+str(correct_cnt/float(len(images))))
    print("Test-Accuracy: "+str((test_correct_cnt/float(len(images)))/10))
    print("---------------------")
# Out:
# Iteration: 1
# Train-Accuracy: 0.179
# Test-Accuracy: 0.4654
# ---------------------
# Iteration: 2
# Train-Accuracy: 0.391
# Test-Accuracy: 0.6557000000000001
# ---------------------
# Iteration: 3
# Train-Accuracy: 0.565
# Test-Accuracy: 0.7261
# ---------------------
# Iteration: 4
# Train-Accuracy: 0.646
# Test-Accuracy: 0.7719
# ---------------------
# Iteration: 5
# Train-Accuracy: 0.678
# Test-Accuracy: 0.7798
# ---------------------
# Iteration: 6
# Train-Accuracy: 0.701
# Test-Accuracy: 0.7828
# ---------------------
# Iteration: 7
# Train-Accuracy: 0.738
# Test-Accuracy: 0.8039
# ---------------------
# Iteration: 8
# Train-Accuracy: 0.767
# Test-Accuracy: 0.8099000000000001
# ---------------------
# Iteration: 9
# Train-Accuracy: 0.788
# Test-Accuracy: 0.8217000000000001
# ---------------------
# Iteration: 10
# Train-Accuracy: 0.797
# Test-Accuracy: 0.8186
# ---------------------
# Iteration: 11
# Train-Accuracy: 0.824
# Test-Accuracy: 0.8225
# ---------------------
# Iteration: 12
# Train-Accuracy: 0.822
# Test-Accuracy: 0.8178000000000001
# ---------------------
# Iteration: 13
# Train-Accuracy: 0.808
# Test-Accuracy: 0.8372999999999999
# ---------------------
# Iteration: 14
# Train-Accuracy: 0.812
# Test-Accuracy: 0.8400000000000001
# ---------------------
# Iteration: 15
# Train-Accuracy: 0.832
# Test-Accuracy: 0.8457000000000001
# ---------------------
# Iteration: 16
# Train-Accuracy: 0.828
# Test-Accuracy: 0.8365
# ---------------------
# Iteration: 17
# Train-Accuracy: 0.851
# Test-Accuracy: 0.8355
# ---------------------
# Iteration: 18
# Train-Accuracy: 0.859
# Test-Accuracy: 0.8352
# ---------------------
# Iteration: 19
# Train-Accuracy: 0.844
# Test-Accuracy: 0.8452
# ---------------------
# Iteration: 20
# Train-Accuracy: 0.878
# Test-Accuracy: 0.8454
# ---------------------
# Iteration: 21
# Train-Accuracy: 0.85
# Test-Accuracy: 0.8408
# ---------------------
# Iteration: 22
# Train-Accuracy: 0.881
# Test-Accuracy: 0.8507999999999999
# ---------------------
# Iteration: 23
# Train-Accuracy: 0.879
# Test-Accuracy: 0.8478
# ---------------------
# Iteration: 24
# Train-Accuracy: 0.885
# Test-Accuracy: 0.8499000000000001
# ---------------------
# Iteration: 25
# Train-Accuracy: 0.883
# Test-Accuracy: 0.8404
# ---------------------
# Iteration: 26
# Train-Accuracy: 0.877
# Test-Accuracy: 0.8422000000000001
# ---------------------
# Iteration: 27
# Train-Accuracy: 0.88
# Test-Accuracy: 0.8465
# ---------------------
# Iteration: 28
# Train-Accuracy: 0.896
# Test-Accuracy: 0.8416
# ---------------------
# Iteration: 29
# Train-Accuracy: 0.876
# Test-Accuracy: 0.8544
# ---------------------
# Iteration: 30
# Train-Accuracy: 0.891
# Test-Accuracy: 0.8545999999999999
# ---------------------
# Iteration: 31
# Train-Accuracy: 0.911
# Test-Accuracy: 0.8534
# ---------------------
# Iteration: 32
# Train-Accuracy: 0.887
# Test-Accuracy: 0.8583999999999999
# ---------------------
# Iteration: 33
# Train-Accuracy: 0.883
# Test-Accuracy: 0.8531000000000001
# ---------------------
# Iteration: 34
# Train-Accuracy: 0.907
# Test-Accuracy: 0.8545
# ---------------------
# Iteration: 35
# Train-Accuracy: 0.908
# Test-Accuracy: 0.8583999999999999
# ---------------------
# Iteration: 36
# Train-Accuracy: 0.914
# Test-Accuracy: 0.8516
# ---------------------
# Iteration: 37
# Train-Accuracy: 0.913
# Test-Accuracy: 0.8526
# ---------------------
# Iteration: 38
# Train-Accuracy: 0.906
# Test-Accuracy: 0.8534
# ---------------------
# Iteration: 39
# Train-Accuracy: 0.906
# Test-Accuracy: 0.8561
# ---------------------
# Iteration: 40
# Train-Accuracy: 0.914
# Test-Accuracy: 0.8513999999999999
# ---------------------
# Iteration: 41
# Train-Accuracy: 0.925
# Test-Accuracy: 0.8601000000000001
# ---------------------
# Iteration: 42
# Train-Accuracy: 0.918
# Test-Accuracy: 0.8598000000000001
# ---------------------
# Iteration: 43
# Train-Accuracy: 0.928
# Test-Accuracy: 0.8622
# ---------------------
# Iteration: 44
# Train-Accuracy: 0.929
# Test-Accuracy: 0.8618
# ---------------------
# Iteration: 45
# Train-Accuracy: 0.924
# Test-Accuracy: 0.8577
# ---------------------
# Iteration: 46
# Train-Accuracy: 0.923
# Test-Accuracy: 0.851
# ---------------------
# Iteration: 47
# Train-Accuracy: 0.927
# Test-Accuracy: 0.8595
# ---------------------
# Iteration: 48
# Train-Accuracy: 0.931
# Test-Accuracy: 0.859
# ---------------------
# Iteration: 49
# Train-Accuracy: 0.935
# Test-Accuracy: 0.8634000000000001
# ---------------------
# Iteration: 50
# Train-Accuracy: 0.926
# Test-Accuracy: 0.8583000000000001
# ---------------------
# Iteration: 51
# Train-Accuracy: 0.93
# Test-Accuracy: 0.8583999999999999
# ---------------------
# Iteration: 52
# Train-Accuracy: 0.936
# Test-Accuracy: 0.8619999999999999
# ---------------------
# Iteration: 53
# Train-Accuracy: 0.938
# Test-Accuracy: 0.8622
# ---------------------
# Iteration: 54
# Train-Accuracy: 0.922
# Test-Accuracy: 0.8646
# ---------------------
# Iteration: 55
# Train-Accuracy: 0.934
# Test-Accuracy: 0.866
# ---------------------
# Iteration: 56
# Train-Accuracy: 0.947
# Test-Accuracy: 0.8688
# ---------------------
# Iteration: 57
# Train-Accuracy: 0.947
# Test-Accuracy: 0.8664999999999999
# ---------------------
# Iteration: 58
# Train-Accuracy: 0.943
# Test-Accuracy: 0.8652
# ---------------------
# Iteration: 59
# Train-Accuracy: 0.94
# Test-Accuracy: 0.8667999999999999
# ---------------------
# Iteration: 60
# Train-Accuracy: 0.943
# Test-Accuracy: 0.8661
# ---------------------
# Iteration: 61
# Train-Accuracy: 0.949
# Test-Accuracy: 0.8634999999999999
# ---------------------
# Iteration: 62
# Train-Accuracy: 0.946
# Test-Accuracy: 0.8622
# ---------------------
# Iteration: 63
# Train-Accuracy: 0.948
# Test-Accuracy: 0.8654
# ---------------------
# Iteration: 64
# Train-Accuracy: 0.948
# Test-Accuracy: 0.8631
# ---------------------
# Iteration: 65
# Train-Accuracy: 0.941
# Test-Accuracy: 0.8673
# ---------------------
# Iteration: 66
# Train-Accuracy: 0.953
# Test-Accuracy: 0.8644000000000001
# ---------------------
# Iteration: 67
# Train-Accuracy: 0.942
# Test-Accuracy: 0.8680999999999999
# ---------------------
# Iteration: 68
# Train-Accuracy: 0.965
# Test-Accuracy: 0.8651
# ---------------------
# Iteration: 69
# Train-Accuracy: 0.955
# Test-Accuracy: 0.8685
# ---------------------
# Iteration: 70
# Train-Accuracy: 0.961
# Test-Accuracy: 0.8672000000000001
# ---------------------
# Iteration: 71
# Train-Accuracy: 0.96
# Test-Accuracy: 0.8694000000000001
# ---------------------
# Iteration: 72
# Train-Accuracy: 0.955
# Test-Accuracy: 0.8663000000000001
# ---------------------
# Iteration: 73
# Train-Accuracy: 0.947
# Test-Accuracy: 0.8664
# ---------------------
# Iteration: 74
# Train-Accuracy: 0.969
# Test-Accuracy: 0.8695999999999999
# ---------------------
# Iteration: 75
# Train-Accuracy: 0.957
# Test-Accuracy: 0.8662000000000001
# ---------------------
# Iteration: 76
# Train-Accuracy: 0.959
# Test-Accuracy: 0.8711
# ---------------------
# Iteration: 77
# Train-Accuracy: 0.959
# Test-Accuracy: 0.8676999999999999
# ---------------------
# Iteration: 78
# Train-Accuracy: 0.961
# Test-Accuracy: 0.8685
# ---------------------
# Iteration: 79
# Train-Accuracy: 0.961
# Test-Accuracy: 0.8701000000000001
# ---------------------
# Iteration: 80
# Train-Accuracy: 0.965
# Test-Accuracy: 0.8635999999999999
# ---------------------
# Iteration: 81
# Train-Accuracy: 0.968
# Test-Accuracy: 0.8703
# ---------------------
# Iteration: 82
# Train-Accuracy: 0.974
# Test-Accuracy: 0.8667
# ---------------------
# Iteration: 83
# Train-Accuracy: 0.983
# Test-Accuracy: 0.8715999999999999
# ---------------------
# Iteration: 84
# Train-Accuracy: 0.963
# Test-Accuracy: 0.8705
# ---------------------
# Iteration: 85
# Train-Accuracy: 0.974
# Test-Accuracy: 0.8709
# ---------------------
# Iteration: 86
# Train-Accuracy: 0.974
# Test-Accuracy: 0.8711
# ---------------------
# Iteration: 87
# Train-Accuracy: 0.974
# Test-Accuracy: 0.8634999999999999
# ---------------------
# Iteration: 88
# Train-Accuracy: 0.963
# Test-Accuracy: 0.8709
# ---------------------
# Iteration: 89
# Train-Accuracy: 0.971
# Test-Accuracy: 0.8698
# ---------------------
# Iteration: 90
# Train-Accuracy: 0.974
# Test-Accuracy: 0.8721
# ---------------------
# Iteration: 91
# Train-Accuracy: 0.98
# Test-Accuracy: 0.8708
# ---------------------
# Iteration: 92
# Train-Accuracy: 0.97
# Test-Accuracy: 0.8737
# ---------------------
# Iteration: 93
# Train-Accuracy: 0.975
# Test-Accuracy: 0.8659000000000001
# ---------------------
# Iteration: 94
# Train-Accuracy: 0.975
# Test-Accuracy: 0.8724999999999999
# ---------------------
# Iteration: 95
# Train-Accuracy: 0.971
# Test-Accuracy: 0.8703
# ---------------------
# Iteration: 96
# Train-Accuracy: 0.969
# Test-Accuracy: 0.8705
# ---------------------
# Iteration: 97
# Train-Accuracy: 0.98
# Test-Accuracy: 0.8701000000000001
# ---------------------
# Iteration: 98
# Train-Accuracy: 0.977
# Test-Accuracy: 0.8739000000000001
# ---------------------
# Iteration: 99
# Train-Accuracy: 0.981
# Test-Accuracy: 0.8708
# ---------------------
# Iteration: 100
# Train-Accuracy: 0.981
# Test-Accuracy: 0.8722
# ---------------------
